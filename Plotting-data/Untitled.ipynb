# %%
# !pip install matplotlib
import pandas as pd
import matplotlib.pyplot as plt 
# %matplotlib inline 
x=[2,3,4]
y=[4,3,2]
print(x,y)
# Out:
# ...
# [2, 3, 4] [4, 3, 2]
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
plt.plot(x,y)

# %%
import pandas as pd
student_df= pd.read_csv("student-data.csv",index_col=0)
student_df.head()
# Out:
#             math_score  science_score  english_score  study_hours  \
# student_id
# 1                   85             78             90            5
# 2                   88             82             85            6
# 3                   90             89             92            7
# 4                   70             75             65            3
# 5                   65             60             70            2
#
#             sleep_hours  attendance_rate  project_score
# student_id
# 1                     7               92             88
# 2                     6               95             85
# 3                     6               98             91
# 4                     8               80             70
# 5                     9               75             65

# %%
student_df.plot()
# Out:
# <Axes: xlabel='student_id'>

# %%
y= [45,98,78,52,63]
plt.plot(y)

# %%
x= ["jan 1", "jan 5", "dec 3", "Aug 5", "Nov 11"]
plt.plot(x,y)

# %%
student_df.plot(x="math_score", y="study_hours", marker='o' , markerfacecolor="red")
# Out:
# <Axes: xlabel='math_score'>

# %%
student_df.plot(x="math_score", y="study_hours", kind="scatter")
# Out:
# <Axes: xlabel='math_score', ylabel='study_hours'>

# %%
emp_df= pd.read_csv("employee-data.csv")
emp_df
# Out:
#    employee_id           name  age department  salary  start_date
# 0          101       John Doe   29      Sales   55000  2020-05-12
# 1          102     Jane Smith   34  Marketing   62000  2018-03-10
# 2          103    Bob Johnson   45         HR   58000  2010-07-01
# 3          104    Alice Brown   31         IT   67000  2019-11-23
# 4          105  Charlie Davis   26    Support   49000  2021-06-15

# %%
emp_df.plot(kind="barh",x="department", y= "salary")
# Out:
# <Axes: ylabel='department'>

# %%
student_df["study_hours"].plot(kind="hist", title= "Study hour analysis")
# Out:
# <Axes: title={'center': 'Study hour analysis'}, ylabel='Frequency'>

# %%
student_df.plot(kind="area", x="study_hours", stacked=False)
# Out:
# <Axes: xlabel='study_hours'>
